# %% [markdown]
# # Preparing training Data
# ####To be run only once

# %%
import collections, itertools
import nltk.classify.util, nltk.metrics
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import stopwords
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.probability import FreqDist, ConditionalFreqDist
import io
import re

def cleandata(mtext):
    mtext = re.sub(' +', ' ', mtext)
    mtext = re.sub('\n+', '.', mtext)
    #mtext = re.sub('[0-9]+. ', '', mtext)
    mtext = re.sub(' -', '.', mtext)
    #mtext = re.sub('\.\.+', '. ', mtext)
    mtext = re.sub('(?<=\\D)\.(?=\\D)', '. ', mtext)
    mtext = ''.join([i if ord(i) < 128 else ' ' for i in mtext])
    mtext = mtext.strip().lower()
    return mtext
    
trainprosraw = io.open("trainpwS.txt", "r", encoding='utf-8')
trainconsraw = io.open("traincwS.txt", "r", encoding='utf-8')

trainpros = []
traincons = []
for line in trainprosraw:
    trainpros.append(line[:-1])
for line in trainconsraw:
    traincons.append(line[:-1])


#trainpros = nltk.sent_tokenize(trainprosraw.read())
#traincons = nltk.sent_tokenize(trainconsraw.read())
#print trainpros
prowords = []
conwords = []
for sent in trainpros:
    prowords.extend(nltk.word_tokenize(sent))
for sent in traincons:
    conwords.extend(nltk.word_tokenize(sent))

trainprosraw.close()
trainconsraw.close()

stpwrds = stopwords.words()
#len(traincons)

# %% [markdown]
# # Building the Classifier
# ####To be run only once

# %%
def evaluate_classifier(featx):
    #negids = movie_reviews.fileids('neg')
    #posids = movie_reviews.fileids('pos')
    
    ##For Movie Review train:
    #negfeats = [(featx(movie_reviews.words(fileids=[f])), 'neg') for f in negids]
    #posfeats = [(featx(movie_reviews.words(fileids=[f])), 'pos') for f in posids]
     
    ##For product reviews train:
    negfeats = [(featx([wrd for wrd in nltk.word_tokenize(con) if wrd not in stpwrds]), 'neg') for con in traincons]
    posfeats = [(featx([wrd for wrd in nltk.word_tokenize(pro) if wrd not in stpwrds]), 'pos') for pro in trainpros]
    
    negcutoff = len(negfeats)*3/4
    poscutoff = len(posfeats)*3/4
 
    trainfeats = negfeats[:] + posfeats[:]
    #trainfeats = negfeats[:negcutoff] + posfeats[:poscutoff]
    testfeats = negfeats[negcutoff:] + posfeats[poscutoff:]
 
    classifier = NaiveBayesClassifier.train(trainfeats)
    refsets = collections.defaultdict(set)
    testsets = collections.defaultdict(set)
 
    for i, (feats, label) in enumerate(testfeats):
            refsets[label].add(i)
            observed = classifier.classify(feats)
            testsets[observed].add(i)
 
    print 'accuracy:', nltk.classify.util.accuracy(classifier, testfeats)
    print 'pos precision:', nltk.metrics.precision(refsets['pos'], testsets['pos'])
    print 'pos recall:', nltk.metrics.recall(refsets['pos'], testsets['pos'])
    print 'neg precision:', nltk.metrics.precision(refsets['neg'], testsets['neg'])
    print 'neg recall:', nltk.metrics.recall(refsets['neg'], testsets['neg'])
    classifier.show_most_informative_features()
    return classifier
    
def word_feats(words):
    return dict([(word, True) for word in words])
 
#print 'evaluating single word features'
#evaluate_classifier(word_feats)
 
word_fd = FreqDist()
label_word_fd = ConditionalFreqDist()
 
for word in prowords:
    word_fd[word.lower()]+=1
    label_word_fd['pos'][word.lower()]+=1
for word in conwords:
    word_fd[word.lower()]+=1
    label_word_fd['neg'][word.lower()]+=1

# n_ii = label_word_fd[label][word]
# n_ix = word_fd[word]
# n_xi = label_word_fd[label].N()
# n_xx = label_word_fd.N()
 
pos_word_count = label_word_fd['pos'].N()
neg_word_count = label_word_fd['neg'].N()
total_word_count = pos_word_count + neg_word_count
 
word_scores = {}
 
for word, freq in word_fd.iteritems():
    pos_score = BigramAssocMeasures.chi_sq(label_word_fd['pos'][word],
        (freq, pos_word_count), total_word_count)
    neg_score = BigramAssocMeasures.chi_sq(label_word_fd['neg'][word],
        (freq, neg_word_count), total_word_count)
    word_scores[word] = pos_score + neg_score

best = sorted(word_scores.iteritems(), key=lambda (w,s): s, reverse=True)[:10000]
bestwords = set([w for w, s in best])
 
def best_word_feats(words):
    return dict([(word, True) for word in words if word in bestwords])
 
#print 'evaluating best word features'
#mc=evaluate_classifier(best_word_feats)
 
def best_bigram_word_feats(words, score_fn=BigramAssocMeasures.chi_sq, n=200):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    d = dict([(bigram, True) for bigram in bigrams])
    d.update(best_word_feats(words))
    return d
 
print 'evaluating best words + bigram chi_sq word features'
mc = evaluate_classifier(best_bigram_word_feats)
# Out:
# evaluating best words + bigram chi_sq word features
# accuracy: 0.988700564972
# pos precision: 0.99
# pos recall: 0.99
# neg precision: 0.987012987013
# neg recall: 0.987012987013
# Most Informative Features
#                sometimes = True              neg : pos    =     13.4 : 1.0
#                     gets = True              neg : pos    =     10.8 : 1.0
#                  problem = True              neg : pos    =      9.9 : 1.0
#                   system = True              neg : pos    =      8.2 : 1.0
#                       ok = True              neg : pos    =      8.2 : 1.0
#                  awesome = True              pos : neg    =      7.4 : 1.0
#                     know = True              neg : pos    =      7.4 : 1.0
#                      bad = True              neg : pos    =      7.4 : 1.0
#                   update = True              neg : pos    =      7.4 : 1.0
#                  display = True              pos : neg    =      6.9 : 1.0

# %% [markdown]
# # Defining features DS

# %%
features = [('Cpu/Processor', ''),
            ('Screen/Display', 'size/inch,resolution/ppi,type/ips/amoled'),
            ('Battery', 'standby,life/day/hour/hrs/usage'),
            ('Camera','front/selfie/secondary,rear/back/primary,flash,low light'),
            ('RAM/Memory', 'expandable/sdcard,available'),
            ('Audio/Sound/Speaker', 'front/earpiece/call,back/loud,music/song,earphone/headphone'),
            ('Build/Design','metal/plastic/glass'),
            ('Heat/temperature', '')]

# %% [markdown]
# # Functions for doing the classification
# ## We use the classifier we created earlier
# ####To be run only once

# %%
import language_check
tool = language_check.LanguageTool('en-US')

def score(item):
    return abs(item[1])-(len(tool.check(item[0]))/float(len(nltk.word_tokenize(item[0]))))/3.0

# %%
def sentanalysis(text):
    result = {}
    complete = []

    tokens = nltk.word_tokenize(text)
    
    d = {}
    for word in tokens:
        d[word] = True
    compdist = mc.prob_classify(d)

    for label in compdist.samples():
        #print("%s: %f" % (label, compdist.prob(label)))
        complete.append(compdist.prob(label))

    sents = nltk.sent_tokenize(text)
    for sent in sents:
        sent = sent.encode('utf-8')
        tokens = nltk.word_tokenize(sent)
        #tokens = [t for t in tokens if t not in stpwrds]
        #print 'tokens: ', tokens 
        if len(set(tokens))>1:
            d = best_bigram_word_feats(tokens)
            #d = {}
            #for word in tokens:
                #d[word] = True
            dist = mc.prob_classify(d)
            #for label in dist.samples():
                #print("%s: %f" % (label, dist.prob(label)))
            result[sent] = []
            result[sent].append(dist.prob('pos'))
            result[sent].append(dist.prob('neg'))

    return (complete, result)

#E.g. of format of f: ('Camera', 'front/selfie/secondary,rear/back/primary')
def findByF(f, items):
    #print items
    subfs = f[1].split(',')
    primf = f[0]
    flist = primf.split('/')
    
    subf_items = {k:[] for k in subfs}
    general_items = []
    count = 0
    for i in items:  
        #first check if item is talking about the feature
        if any([fi.lower().strip() in i[0] for fi in flist]):
            count+=1
            #print ('\t\t\t# '+i[0])
            hasSF = False
            #find which subfeature does the item belong to
            if subfs != ['']:              
                for sf in subfs:
                    sflist = sf.split('/')
                    if any([sfi.lower().strip() in i[0] for sfi in sflist]):
                        subf_items[sf].append(i)
                        hasSF = True
                    
            if not hasSF:          
                general_items.append(i)
    
    print "(" + str(count) + "):"
    
    for sf in subf_items:
        subf_items[sf].sort(key=score, reverse=True)
        if subf_items[sf]!=[]:
            print '\t\t' + sf + ' (' + str(len(subf_items[sf])) + "):"
            for item in subf_items[sf]:
                print '\t\t\t\t> ' + item[0]
    
    if general_items != []:
        general_items.sort(key=score, reverse=True)
        print '\t\tGeneral (' + str(len(general_items)) + "):"
        for item in general_items:
            print '\t\t\t\t> ' + item[0]
    
def thefunction(mtext):
    comp, res = sentanalysis(mtext)
    for i in res:
        res[i] = res[i][0]-res[i][1]
    items = sorted(res.items(), key = lambda i: -abs(i[1]))
    pros, cons = assignPC(items,0.1)
    printByFeatures(pros, cons)

def assignPC(items, sensitivity):
    pros=[]
    cons=[]
    for i in items:
        if i[1]>sensitivity:
            pros.append(i)
        elif i[1]<(-1*sensitivity):
            cons.append(i)
    return pros,cons

def printAll(items):
    for i in items:
        print ('\t\t> '+i[0])

def printByFeatures(pros, cons):
    for f in features:
        print "---------------"
        print(f[0])
        print("\tPROS"),
        findByF(f, pros)
        print("\tCONS"),
        findByF(f, cons)
    print("\n\tALLPROS (" + str(len(pros)) + "):")
    printAll(pros)
    print("\n\tALLCONS (" + str(len(cons)) + "):")
    printAll(cons)

# %% [markdown]
# # Getting input from file
# ###Run this whenever data is changed

# %%
mtextfile = io.open("test.txt", "r", encoding='utf-8')
mtext = mtextfile.read()
mtextfile.close()

matches = tool.check(mtext)


mtext = cleandata(mtext)

# %%
#print (mtext)
print "Language errors:", len(matches)
thefunction(mtext)
# Out:
# Language errors: 268
# ---------------
# Cpu/Processor
# 	PROS (7):
# 		General (7):
# 				> the relatively power efficient processor and big battery (3100 mah) gives the note 4g excellent battery life.
# 				> .7. it has better build quality, screen display, touch sensitivity, cameas, speakers, cpu-ram-operating system-interface-battery backup.
# 				> while the previous model was based on an octa-core mediatek mt6592 processor, the 4g version uses a qualcomm snapdragon 400. the main reason for this is qualcomm's integrated lte capabilities, but there's a very interesting side effect in india.
# 				> chipset: mali 400 mp2.processor (cpu): 1.3ghz quad-core.
# 				> android v5 lollipop operating system with 1.3ghz quad core processor, 1gb ram, 8gb internal memory expandable up to 32gb and dual sim (gsm+gsm).
# 				> .1.3ghz quad core processor and mali 400 mp2 graphic processor powers the titanium mach one.
# 				> the mt6592 usually has an advantage in cpu-intensive tasks but loses out in the graphics department.
# 	CONS (1):
# 		General (1):
# 				> cpu heats a slight while using continous 3g(i guess it's the issue with many phones).
# ---------------
# Screen/Display
# 	PROS (11):
# 		resolution/ppi (1):
# 				> size & resolution: 4.7  hd screen 1280 x 720.primary camera: 8mp with led flash.
# 		type/ips/amoled (4):
# 				> ?display:4.7 ips hd display makes it a premium one at this price.
# 				> its selfie camera is just mind blowing and screen quality is beat at its price with ips hd screen.
# 				> display type: ips display.
# 				> it has a 4.7-inch hd ips screen with 8gb internal storage.
# 		size/inch (3):
# 				> the 720p hd display is good but not great with 5.5 inch screen.
# 				> size & resolution: 4.7  hd screen 1280 x 720.primary camera: 8mp with led flash.
# 				> it has a 4.7-inch hd ips screen with 8gb internal storage.
# 		General (5):
# 				> it's reasonably wide and tall, but you'll definitely feel its weight and you'll have to balance it carefully in order to reach all parts of the screen with one hand.
# 				> purchased on 4th jul 2015, using since 3 days and experiencing very good performance, very slim and light weight, good display, fare battery life last long for 12 to 14 hrs, value for money, best at its price range.
# 				> there are some very good features: one hand operation mode in which the display becomes suitable for using us with one hand.
# 				> .7. it has better build quality, screen display, touch sensitivity, cameas, speakers, cpu-ram-operating system-interface-battery backup.
# 				> display: display is brilliant.
# 	CONS (7):
# 		size/inch (1):
# 				> as far as phones with 5.5-inch screens go, the redmi note 4g isn't all that difficult to handle.
# 		General (6):
# 				> the screens on both models are the same 5.5" 720x1280 panels, and there's still 2gb of ram and 8gb of internal storage space.
# 				> as we've come to expect, all icons and widgets live together on the homescreens and there is no separate app drawer.
# 				> the black front face is offset by a shiny white rear shell and very noticeable red icons for the three capacitive buttons below the screen.
# 				> .5. apart from the charger and the usb cable, no other accessory( like screen-guard, flip-cover, sim-adapter, etc. )
# 				> touchscreen not very responsive.
# 				> you can play around with settings for the buttons, notifications led, lockscreen and more.
# ---------------
# Battery
# 	PROS (8):
# 		life/day/hour/hrs/usage (3):
# 				> purchased on 4th jul 2015, using since 3 days and experiencing very good performance, very slim and light weight, good display, fare battery life last long for 12 to 14 hrs, value for money, best at its price range.
# 				> the relatively power efficient processor and big battery (3100 mah) gives the note 4g excellent battery life.
# 				> battery is good last for a day with mod.
# 		General (5):
# 				> the low capacity battery can give you a pretty good battery backup for the budget price.
# 				> .7. it has better build quality, screen display, touch sensitivity, cameas, speakers, cpu-ram-operating system-interface-battery backup.
# 				> battery and camera.
# 				> ?battery:good enough but not great.
# 				> .2. battery back up.
# 	CONS (9):
# 		life/day/hour/hrs/usage (3):
# 				> seriously guys i am using this phone past 7 days and was amazed to see that even if you play heavy games from day 1, you won't find your phone getting heated or battery drainage.
# 				> for most users, it is safe to say that it will give a battery life of around 16 to 18 hours.
# 				> battery charging takes more than 2 hours to charge and within an hour it drains up and only 50% remains.
# 		General (6):
# 				> charging time: since the battery is huge so it take a large time to charge.
# 				> you still need to take out the battery in order to swap sim and microsd cards.
# 				> battery: 1800mah.
# 				> games like asphalt8, smash hit when started phone hand and only solution remaining is removing battery.4.
# 				> 1800mah lithium-ion battery.
# 				> and ofcourse the battery.
# ---------------
# Camera
# 	PROS (14):
# 		front/selfie/secondary (7):
# 				> it has an 8mp back camera and 5mp front camera with led flash on both sides.
# 				> its selfie camera is just mind blowing and screen quality is beat at its price with ips hd screen.
# 				> .6. the front camera is very good for selfie.
# 				> camera is disappointing both front & rear.
# 				> secondary camera: 5mp with led flash.
# 				> the device is available in three colour variants i. e.  white-silver, white- gold and black-blue.8mp primary camera with auto focus, flash and 5mp front facing camera with special selfie mode and flash.
# 				> the phone has advanced camera features such as  blink capture  and  voice capture  and numerous photo modes comprising of panorama view, continuous shot and selfie mode.
# 		flash (4):
# 				> it has an 8mp back camera and 5mp front camera with led flash on both sides.
# 				> size & resolution: 4.7  hd screen 1280 x 720.primary camera: 8mp with led flash.
# 				> secondary camera: 5mp with led flash.
# 				> the device is available in three colour variants i. e.  white-silver, white- gold and black-blue.8mp primary camera with auto focus, flash and 5mp front facing camera with special selfie mode and flash.
# 		rear/back/primary (5):
# 				> the note 4g packs in a very good rear camera.
# 				> it has an 8mp back camera and 5mp front camera with led flash on both sides.
# 				> size & resolution: 4.7  hd screen 1280 x 720.primary camera: 8mp with led flash.
# 				> camera is disappointing both front & rear.
# 				> the device is available in three colour variants i. e.  white-silver, white- gold and black-blue.8mp primary camera with auto focus, flash and 5mp front facing camera with special selfie mode and flash.
# 		General (5):
# 				> the level of detail is less than what we usually expect from a 13-megapixel camera but keeping in mind the price of the phone, we have to say that it does well.
# 				> camera:it is good but not excellent.
# 				> camera quality is also good.
# 				> battery and camera.
# 				> camera quality is also good with a feature called age detecter.
# 	CONS (5):
# 		General (5):
# 				> ?camera:its an other selling point of this device with 8mp+5mp camera pair.
# 				> the phones in this range with 13mp camera are giving a grainy,non-superfine image.
# 				> the 13-megapixel cameras are also identical, as are the bluetooth 4.0, gps and fm radio features.
# 				> overall it surpasses the yureka and redmi's camera.
# 				> camera is satisfactory or you can say above average.
# ---------------
# RAM/Memory
# 	PROS (4):
# 		expandable/sdcard (2):
# 				> memory: 8 gb internal, expandable to 32gb via microsd slot.
# 				> android v5 lollipop operating system with 1.3ghz quad core processor, 1gb ram, 8gb internal memory expandable up to 32gb and dual sim (gsm+gsm).
# 		General (2):
# 				> .7. it has better build quality, screen display, touch sensitivity, cameas, speakers, cpu-ram-operating system-interface-battery backup.
# 				> the phone has advanced camera features such as  blink capture  and  voice capture  and numerous photo modes comprising of panorama view, continuous shot and selfie mode.
# 	CONS (4):
# 		General (4):
# 				> cons:i found the ram usage a bit high when the phone is idle.
# 				> the screens on both models are the same 5.5" 720x1280 panels, and there's still 2gb of ram and 8gb of internal storage space.
# 				> now about specs 2gb ram is enough for playing modern combat or fifa 15. you can find such phones being sold by samsung and sony at 30 to 35 k.  internal 8 gb might be less for people who keep their phone stuffed but then you havean advantage of rooting the phone without losing its warranty.
# 				> ram: 1 gb.
# ---------------
# Audio/Sound/Speaker
# 	PROS (4):
# 		earphone/headphone (1):
# 				> sound in earphone is also clear and surround.
# 		back/loud (2):
# 				> .7. it has better build quality, screen display, touch sensitivity, cameas, speakers, cpu-ram-operating system-interface-battery backup.
# 				> at loudspeaker is crisp and clear.
# 		General (1):
# 				> sound is good with my nokia and philips she3900bk hradphones.
# 	CONS (5):
# 		back/loud (2):
# 				> when we hold in our hand the loudspeaker gets covered.
# 				> loudspeaker: i found it loud.
# 		front/earpiece/call (1):
# 				> speaker quality very poor when enabled during call.
# 		General (2):
# 				> there's a massive variety of ringtones and message alert sounds to choose from.
# 				> sound is ok. n if u butly a 6k phone kindly dont compare it with high end phones.
# ---------------
# Build/Design
# 	PROS (6):
# 		metal/plastic/glass (1):
# 				> even though the entire casing is plastic the build quality is pretty great.
# 		General (5):
# 				> ?design:a great looking phone for such a budget price.
# 				> .7. it has better build quality, screen display, touch sensitivity, cameas, speakers, cpu-ram-operating system-interface-battery backup.
# 				> build:quality is best.
# 				> its too slim as if like iphone 6 design.
# 				> phone looks very good i like it's design but there are some problem with this phone.1.
# 	CONS (0):
# ---------------
# Heat/temperature
# 	PROS (0):
# 	CONS (10):
# 		General (10):
# 				> seriously guys i am using this phone past 7 days and was amazed to see that even if you play heavy games from day 1, you won't find your phone getting heated or battery drainage.
# 				> the only time it gets heated when you keep it on charging for the first time because it is the case with every android phone.
# 				> ?about heating:yes!
# 				> dont believe on the fake reviews that it heats up a lot as if its temperature is from 25 to 28 degree.
# 				> the heat generated when backcover is put, is an issue that needs some attention.
# 				> cpu heats a slight while using continous 3g(i guess it's the issue with many phones).
# 				> there is a little heating issue but its a smartphone n every smarthphpne does get heated.
# 				> haven't noticed any kind of heating.
# 				> but less heating compared to yureka.
# 				> .2. heating issue.3.
#
# 	ALLPROS (122):
# 		> its selfie camera is just mind blowing and screen quality is beat at its price with ips hd screen.
# 		> the 720p hd display is good but not great with 5.5 inch screen.
# 		> purchased on 4th jul 2015, using since 3 days and experiencing very good performance, very slim and light weight, good display, fare battery life last long for 12 to 14 hrs, value for money, best at its price range.
# 		> it has an 8mp back camera and 5mp front camera with led flash on both sides.
# 		> the features are mind boggling,the front cam and its flash in particular are awesome!!!
# 		> it is a capable device and offers very good smartphone experience at a very nice price point.
# 		> the low capacity battery can give you a pretty good battery backup for the budget price.
# 		> the note 4g packs in a very good rear camera.
# 		> .7. it has better build quality, screen display, touch sensitivity, cameas, speakers, cpu-ram-operating system-interface-battery backup.
# 		> even though the entire casing is plastic the build quality is pretty great.
# 		> it clicks 13-megapixel images and when used in daylight, it clicks photos that sharp, clear and have good colours.
# 		> size & resolution: 4.7  hd screen 1280 x 720.primary camera: 8mp with led flash.
# 		> at a price of rs.7,999 the redmi note 4g is an excellent value for money.
# 		> the colours in images are punchy, especially if you have taken care of holding the phone steady and if the light is good.
# 		> the back-illuminated sensor makes it capable of capturing excellent low light images.
# 		> ?display:4.7 ips hd display makes it a premium one at this price.
# 		> .6. the front camera is very good for selfie.
# 		> the relatively power efficient processor and big battery (3100 mah) gives the note 4g excellent battery life.
# 		> its too slim as if like iphone 6 design.
# 		> we've seen devices with qualcomm's quad-core snapdragon 400 and mediatek's octa-core mt6592 go head-to-head before, but never two that were so closely matched in all other regards.
# 		> the 4g version of this phone has only a single regular-sized sim card slot.
# 		> the hands-on experience is pretty premium and it is light enough.
# 		> the level of detail is less than what we usually expect from a 13-megapixel camera but keeping in mind the price of the phone, we have to say that it does well.
# 		> dimensions: 137.00 x 68.00 x 8.10.games like morden combat, blood n glory, contract killer etc runs good without lag.
# 		> the front snapper can take great selfies.
# 		> it's reasonably wide and tall, but you'll definitely feel its weight and you'll have to balance it carefully in order to reach all parts of the screen with one hand.
# 		> themes,scrolling effects,and the quick settings,gestures(double tap one is awesome).
# 		> the device is available in three colour variants i. e.  white-silver, white- gold and black-blue.8mp primary camera with auto focus, flash and 5mp front facing camera with special selfie mode and flash.
# 		> the whole look is pretty understated.
# 		> memory: 8 gb internal, expandable to 32gb via microsd slot.
# 		> the notifications shade is also clean, and you can choose whether to show quick settings shortcuts in a separate page or in a scrolling bar at the bottom.
# 		> phone is just awesome.
# 		> very average & with regular sim slot had to change the sim from micro to regular to check the full feature of the phone.
# 		> which feels great and stylish.
# 		> yeah offcourse good features in low price but!!!
# 		> camera is disappointing both front & rear.
# 		> the xiaomi redmi note 4g did not feel any different to use than the earlier model did, and users should be quite happy with the way this device handles everyday tasks.
# 		> secondary camera: 5mp with led flash.
# 		> but the actual experience with the phone is somewhat different.
# 		> there are some very good features: one hand operation mode in which the display becomes suitable for using us with one hand.
# 		> display type: ips display.
# 		> and the color reproduction is better than most in the same range.
# 		> the 8mp backshooter really takes good shots with nice details.
# 		> he is very happy now and fully enjoying with this value for money model.
# 		> camera:it is good but not excellent.
# 		> build:quality is best.
# 		> ?design:a great looking phone for such a budget price.
# 		> at loudspeaker is crisp and clear.
# 		> it feels great having it.
# 		> but i have noticed some lag in modern combat 5 though its still playable.
# 		> camera quality is also good.
# 		> in low light, the performance is not so good but it is also not terrible.
# 		> .3. butter smooth swipe.
# 		> i bought it at price of 5000 and its really value for money phone.
# 		> display: display is brilliant.
# 		> chipset: mali 400 mp2.processor (cpu): 1.3ghz quad-core.
# 		> the redmi note 4g shares most of its specifications with the redmi model, with one key difference.
# 		> so overall it was a good experience on zen ui also.
# 		> ?also did some gaming-played asphalt 8,real racing,traffic racer,dead trigger 2 and some other games.
# 		> tried playing temple run,real racing and some small games and it really handles it nicely.
# 		> everything looks crisp and clean, without being over the top.
# 		> while the previous model was based on an octa-core mediatek mt6592 processor, the 4g version uses a qualcomm snapdragon 400. the main reason for this is qualcomm's integrated lte capabilities, but there's a very interesting side effect in india.
# 		> battery is good last for a day with mod.
# 		> the viewing angles may not be that great but is enough.
# 		> xiaomi includes an online wallpaper catalog within the settings app itself.
# 		> sound is good with my nokia and philips she3900bk hradphones.
# 		> while taking selfies.
# 		> amazing phone.
# 		> price should have been @ 4000/- .
# 		> battery and camera.
# 		> this is the best smartphone you can buy at such a low price!!!!.
# 		> pros:.1. price .
# 		> in this price range.
# 		> i purchased redmi note 4g from flipkart about 2 months ago.
# 		> the phone has advanced camera features such as  blink capture  and  voice capture  and numerous photo modes comprising of panorama view, continuous shot and selfie mode.
# 		> both models have accelerometers, gyroscopes, digital compasses and proximity sensors.
# 		> reading mode,vivid modes,floating calculator etc are some of the features i overcame.
# 		> camera quality is also good with a feature called age detecter.
# 		> hello friends!!!!
# 		> android v5 lollipop operating system with 1.3ghz quad core processor, 1gb ram, 8gb internal memory expandable up to 32gb and dual sim (gsm+gsm).
# 		> performance: awesome,no lags and a slight bugs i found in the zen ui.
# 		> ( i just updated my redmi note 4g to miui 6).
# 		> and its perfect for single handed usage.
# 		> .1.3ghz quad core processor and mali 400 mp2 graphic processor powers the titanium mach one.
# 		> in this price range no doubt for that.
# 		> absolutely!!.
# 		> its the best.
# 		> the mt6592 usually has an advantage in cpu-intensive tasks but loses out in the graphics department.
# 		> sound in earphone is also clear and surround.
# 		> .5. no lag on playing high end games.
# 		> very handy.
# 		> my primary phone is xiaomi mi4.
# 		> and i thought this model comes with a fast charger but it doesn't.
# 		> with no flip cover at this price point for a 3g phone feels slightly highly priced .
# 		> there are plenty of options in the market at 4999/-.
# 		> the front earpiece are metallic.
# 		> ?battery:good enough but not great.
# 		> there are quite a few options to discover in the redmi note's settings app.
# 		> led flash may not be very effective under presence of other sources of light like daylight.
# 		> i am very experienced in gadgets.
# 		> thanks karbonn.
# 		> phone looks very good i like it's design but there are some problem with this phone.1.
# 		> (i haven't tested in sunlight).
# 		> have a good time.
# 		> its affordable, reliable, and highly recommended.
# 		> so, friends here is my review-.
# 		> (top 10 reviewer) .
# 		> else, mentally prepare yourself to charge it atleast twice a day if not thrice.
# 		> thanks for reading my review and bearing my thoughts.
# 		> .9. light weight.10.
# 		> -------------------------------------------------------------.
# 		> -------------------------.
# 		> ---------------------------.
# 		> .2. battery back up.
# 		> !.
# 		> it has a 4.7-inch hd ips screen with 8gb internal storage.
# 		> the note 4g is a perfect choice.
# 		> it has great filters and modes:gif animation,time rewind,smart remove etc.
# 		> thanks to legal hurdles brought on by a patent infringement dispute with ericsson, xiaomi has been restrained from selling mediatek-based products in the country.
# 		> it crosses 55%.
# 		> .4. music player come with good settings like shake to change song, headphone configuration etc.
# 		> !.39 of 42 people found the following review helpful.4.0 out of 5 stars at this price its even better!
#
# 	ALLCONS (117):
# 		> there is a little heating issue but its a smartphone n every smarthphpne does get heated.
# 		> this is something users who like simplicity might prefer, but we feel hampered because it's difficult to arrange widgets, and as we install more apps, things get really disorganised.
# 		> the only time it gets heated when you keep it on charging for the first time because it is the case with every android phone.
# 		> it does get a little hot at sometimes on extensive gaming but still i don't think its a deal breaker.
# 		> battery charging takes more than 2 hours to charge and within an hour it drains up and only 50% remains.
# 		> seriously guys i am using this phone past 7 days and was amazed to see that even if you play heavy games from day 1, you won't find your phone getting heated or battery drainage.
# 		> the system app icons are also customised, and thankfully they aren't too difficult to tell apart.
# 		> for most users, it is safe to say that it will give a battery life of around 16 to 18 hours.
# 		> i have mi4, redmi note 4g, mi pad, redmi 1s, nexus 7 and one plus one.
# 		> cons:i found the ram usage a bit high when the phone is idle.
# 		> cpu heats a slight while using continous 3g(i guess it's the issue with many phones).
# 		> charging time: since the battery is huge so it take a large time to charge.
# 		> which can be fixed in small ota update.
# 		> friends are you hesitating to buy this phone because it is a chinese phone and you have nevr hear of the company before?
# 		> this phones has pro n cons but i have been using karbonn from past 3 years n this is my 4th handset i dont see any issues with phone.
# 		> speaker quality very poor when enabled during call.
# 		> dont believe on the fake reviews that it heats up a lot as if its temperature is from 25 to 28 degree.
# 		> i bought it 9 /07/15 and found that shocking reality ;; it is causing an irritation to heart and brain whenever i use it if feel my heart beat lowering along with head ache.
# 		> the heat generated when backcover is put, is an issue that needs some attention.
# 		> but make sure to keep the phone still, while low lightshots.
# 		> the buttons are lined up on the right edge, while the left is blank.
# 		> xiaomi also has service centers all over india.
# 		> xiaomi uses a non-standard squared-off micro-usb port which makes it difficult to see which way the plug needs to go in.
# 		> now about specs 2gb ram is enough for playing modern combat or fifa 15. you can find such phones being sold by samsung and sony at 30 to 35 k.  internal 8 gb might be less for people who keep their phone stuffed but then you havean advantage of rooting the phone without losing its warranty.
# 		> so can't tell about that).
# 		> a qualcomm version allows the company to keep selling this product in india while the case is being heard.
# 		> the ui is also very stable and xiaomi also promises future software updates.
# 		> there's a massive variety of ringtones and message alert sounds to choose from.
# 		> the touch capacitive buttons are back-lit.
# 		> as we've come to expect, all icons and widgets live together on the homescreens and there is no separate app drawer.
# 		> the screens on both models are the same 5.5" 720x1280 panels, and there's still 2gb of ram and 8gb of internal storage space.
# 		> ?about heating:yes!
# 		> .3. not very suitable for rough-use, and needs a bit of careful handling.4.
# 		> [5000mah power bank recommended.
# 		> when used to access two social media accounts, two email accounts, web browsing for nearly an hour, calls for nearly an hour, some gaming and little of photography, the phone lasts around 14 hours.
# 		> but less heating compared to yureka.
# 		> ?camera:its an other selling point of this device with 8mp+5mp camera pair.
# 		> as far as phones with 5.5-inch screens go, the redmi note 4g isn't all that difficult to handle.
# 		> in low light if you hold the phone steady while clicking an image, you will be able to snap photos that you can share on social media.
# 		> ram: 1 gb.
# 		> it is just a normal brushed aluminium finish on a plastic case.
# 		> it is a safe buy if you are looking to get a smartphone for less than rs.10,000.
# 		> i also tried playing the gt-racing 2 with full graphics and the device struggle a bit while race beginning.
# 		> haven't noticed any kind of heating.
# 		> should you buy it?
# 		> are provided with this mobile handset.
# 		> .5. apart from the charger and the usb cable, no other accessory( like screen-guard, flip-cover, sim-adapter, etc. )
# 		> i would try to keep it clean and simple.
# 		> almost 3 hours from 0 to 100%.
# 		> ?did some benchamarking:.
# 		> the black front face is offset by a shiny white rear shell and very noticeable red icons for the three capacitive buttons below the screen.
# 		> zen ui: i have used cyanogen os and miui, i think zen ui also has customiztion features like them.
# 		> touchscreen not very responsive.
# 		> [+updated 09-july-2015], 1 july 2015.by abraham.
# 		> i have set the double tap technique to overcome this issue.
# 		> the phones in this range with 13mp camera are giving a grainy,non-superfine image.
# 		> sometimes.
# 		> there's only a small silver mi logo on the lower back and no branding on the front.
# 		> xiaomi's miui skin is one of the most polished we've seen from the major chinese manufacturers.
# 		> usb: micro usb.
# 		> cons:.1. single sim slot.2.
# 		> see all my reviews.
# 		> the 13-megapixel cameras are also identical, as are the bluetooth 4.0, gps and fm radio features.
# 		> most people don't wanna buy this phone because it is a karbonn branded phone and they actually don't trust the brand and its quality.
# 		> gps: yes.
# 		> karbon titanium mach one specifications:.
# 		> when we hold in our hand the loudspeaker gets covered.
# 		> performance.
# 		> however when i first purchased redmi 1s, it was the best phone ever.
# 		> volume rocker:it's an awesome placement of button.
# 		> you still need to take out the battery in order to swap sim and microsd cards.
# 		> loudspeaker: i found it loud.
# 		> please consider this before buying your health is of primary importance it may be because of any harmfull radiatins from this worst ever phone '" karbonn'.
# 		> battery: 1800mah.
# 		> karbon machone is a complete package with such a low price tag.
# 		> its easy to control this device.
# 		> the rear shell is a bit difficult to pry off, but the first major difference between the xiaomi note twins is visible beneath it.
# 		> also hangs once in a while.
# 		> however in this case, the snapdragon 400 lagged behind across the board.
# 		> update 09-july-2015.-----------------------------------.
# 		> sound is ok. n if u butly a 6k phone kindly dont compare it with high end phones.
# 		> ].
# 		> grab it .
# 		> which we wont find in this budget.
# 		> .2. heating issue.3.
# 		> games like asphalt8, smash hit when started phone hand and only solution remaining is removing battery.4.
# 		> look and feel.
# 		> overall it surpasses the yureka and redmi's camera.
# 		> microsd capacity support has been bumped up to 64gb, and there's faster wi-fi 802.11ac support.
# 		> i think that can be ignored.
# 		> 4g service is unavailable in many places in india.
# 		> you can check them out to get an idea).
# 		> the headset socket is on top and the micro-usb port is on the bottom.
# 		> even left hand person can use this feature.
# 		> os: android 4.4 kitkat.
# 		> camera is satisfactory or you can say above average.
# 		> you can change the transition animation and some other visual effects if you like.
# 		> you can play around with settings for the buttons, notifications led, lockscreen and more.
# 		> i have got a chance to use the phone for a week and here's my review.
# 		> really amazing product i bought for my son.
# 		> overall average smartphone.
# 		> use.
# 		> do not worry friends, this was the same case with me.
# 		> ( i have attached pics clicked with redmi note 4g with the review.
# 		> the 3,100mah batteries also appear to be exactly the same as redmi note 3g.
# 		> and muting the alarm,calls.
# 		> and the lock button placement is not at all handy.
# 		> and ofcourse the battery.
# 		> 1800mah lithium-ion battery.
# 		> on 3g it runs for 6 hours and on wifi it runs for 7-8 hours.
# 		> though decent, needs a power bankif you want to enjoy uninterupted entertainment.
# 		> (i haven't tested it in low light either.
# 		> it runs on android os 4.4 kit kat upgradable to android lollipop.
# 		> no lags at all.
# 		> the redmi note 4g consistently performed just a little bit slower than the original redmi note did.
# 		> we had no trouble running common apps and light games.
# 		> and it did handle the games with ease.
